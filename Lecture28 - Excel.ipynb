# %%
import pandas as pd
import numpy as np
import xlrd
import openpyxl

# %%
# install xlrd
# install openpyxl

# %%
filnm = '/Users/eshelman/Documents/EPMS Cost Comparisons.xlsx'

# %%
xlsfile = pd.ExcelFile(filnm)

# %%
df = xlsfile.parse('Master Data Sheet')

# %%
df.head(n=20)
# Out:
#                     Vendor         Region  Description  Value    Loc    Phase
# 0   Schneider Electric USA  IAD74 Phase 1     PM Hours    112  IAD74  Phase 1
# 1   Schneider Electric USA  IAD74 Phase 2     PM Hours     96  IAD74  Phase 2
# 2   Schneider Electric USA  IAD74 Phase 3     PM Hours     96  IAD74  Phase 3
# 3   Schneider Electric USA    PDX Phase 1     PM Hours    112    PDX  Phase 1
# 4   Schneider Electric USA    PDX Phase 2     PM Hours     96    PDX  Phase 2
# 5   Schneider Electric USA    PDX phase 3     PM Hours     96    PDX  phase 3
# 6   Schneider Electric USA    SFO Phase 1     PM Hours    112    SFO  Phase 1
# 7   Schneider Electric USA    SFO Phase 2     PM Hours     96    SFO  Phase 2
# 8   Schneider Electric USA    SFO Phase 3     PM Hours     96    SFO  Phase 3
# 9   Schneider Electric USA    CMH Phase 1     PM Hours    112    CMH  Phase 1
# 10  Schneider Electric USA    CMH Phase 2     PM Hours     96    CMH  Phase 2
# 11  Schneider Electric USA    CMH Phase 3     PM Hours     96    CMH  Phase 3
# 12  Schneider Electric USA  IAD74 Phase 1  Hourly Rate    179  IAD74  Phase 1
# 13  Schneider Electric USA  IAD74 Phase 2  Hourly Rate    179  IAD74  Phase 2
# 14  Schneider Electric USA  IAD74 Phase 3  Hourly Rate    179  IAD74  Phase 3
# 15  Schneider Electric USA    PDX Phase 1  Hourly Rate    179    PDX  Phase 1
# 16  Schneider Electric USA    PDX Phase 2  Hourly Rate    179    PDX  Phase 2
# 17  Schneider Electric USA    PDX phase 3  Hourly Rate    179    PDX  phase 3
# 18  Schneider Electric USA    SFO Phase 1  Hourly Rate    179    SFO  Phase 1
# 19  Schneider Electric USA    SFO Phase 2  Hourly Rate    179    SFO  Phase 2

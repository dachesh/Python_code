# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
ds1 = randn(100)

# %%
plt.hist(ds1)
# Out:
# (array([  1.,   3.,   7.,   5.,  14.,  16.,  24.,  13.,  11.,   6.]),
#  array([-2.97701602, -2.47174989, -1.96648376, -1.46121763, -0.9559515 ,
#         -0.45068537,  0.05458075,  0.55984688,  1.06511301,  1.57037914,
#          2.07564527]),
#  <a list of 10 Patch objects>)

# %%
ds2 = randn(80)
plt.hist(ds2,color='indianred')
# Out:
# (array([  2.,   4.,   5.,  12.,   7.,  13.,  22.,   8.,   3.,   4.]),
#  array([-2.3970357 , -1.93982563, -1.48261555, -1.02540548, -0.56819541,
#         -0.11098534,  0.34622474,  0.80343481,  1.26064488,  1.71785495,
#          2.17506503]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(ds1,normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(ds2,normed=True,color='blue',alpha=0.5,bins=20)
# Out:
# (array([ 0.10935892,  0.        ,  0.10935892,  0.10935892,  0.21871784,
#          0.05467946,  0.21871784,  0.43743568,  0.16403838,  0.21871784,
#          0.38275622,  0.32807676,  0.92955083,  0.2733973 ,  0.21871784,
#          0.21871784,  0.16403838,  0.        ,  0.16403838,  0.05467946]),
#  array([-2.3970357 , -2.16843066, -1.93982563, -1.71122059, -1.48261555,
#         -1.25401052, -1.02540548, -0.79680045, -0.56819541, -0.33959037,
#         -0.11098534,  0.1176197 ,  0.34622474,  0.57482977,  0.80343481,
#          1.03203984,  1.26064488,  1.48924992,  1.71785495,  1.94645999,
#          2.17506503]),
#  <a list of 20 Patch objects>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')

# %%
sns.jointplot(data1,data2,kind='hex',color='orange')
